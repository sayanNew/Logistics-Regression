# %%
#1. What is Simple Linear Regression (SLR)? Explain its purpose.

'''
Simple Linear Regression (SLR) is a statistical method that shows the relationship between one independent variable (X) and one dependent variable (Y) using a straight-line equation:
Y=a+bX
Purpose:
To understand how one variable affects another
To predict the value of Y based on X
To identify the trend (positive or negative relationship)
'''
# Out:
# '\nSimple Linear Regression (SLR) is a statistical method that shows the relationship between one independent variable (X) and one dependent variable (Y) using a straight-line equation:\nY=a+bX\nPurpose:\nTo understand how one variable affects another\nTo predict the value of Y based on X\nTo identify the trend (positive or negative relationship)\n'

# %%
#2. What are the key assumptions of Simple Linear Regression?

'''
The key assumptions of Simple Linear Regression (SLR) are:

Linearity
The relationship between X (independent variable) and Y (dependent variable) is linear.
Independence of Errors
The residuals (errors) are independent of each other.
Homoscedasticity
The variance of errors is constant for all values of X.
Normality of Errors
The residuals are normally distributed.
No Significant Outliers
There are no extreme values that strongly influence the regression line.

These assumptions ensure that the model is reliable and produces accurate results.
'''
# Out:
# '\nThe key assumptions of Simple Linear Regression (SLR) are:\n\nLinearity\nThe relationship between X (independent variable) and Y (dependent variable) is linear.\nIndependence of Errors\nThe residuals (errors) are independent of each other.\nHomoscedasticity\nThe variance of errors is constant for all values of X.\nNormality of Errors\nThe residuals are normally distributed.\nNo Significant Outliers\nThere are no extreme values that strongly influence the regression line.\n\nThese assumptions ensure that the model is reliable and produces accurate results.\n'

# %%
#3. Write the mathematical equation for a simple linear regression model and explain each term.

'''
The equation of a Simple Linear Regression (SLR) model is:
Y=a+bX+ε
Y: Dependent variable (predicted value)
X: Independent variable (input/predictor)
a: Intercept (value of Y when X = 0)
b: Slope (change in Y for one unit change in X)
ε: Error term (difference between actual and predicted value)
'''
# Out:
# '\nThe equation of a Simple Linear Regression (SLR) model is:\nY=a+bX+ε\nY: Dependent variable (predicted value)\nX: Independent variable (input/predictor)\na: Intercept (value of Y when X = 0)\nb: Slope (change in Y for one unit change in X)\nε: Error term (difference between actual and predicted value)\n'

# %%
#4. Provide a real-world example where simple linear regression can be applied.

'''
A real-world example of Simple Linear Regression (SLR) is predicting house prices based on size.

X (independent variable): Size of the house (in square feet)
Y (dependent variable): Price of the house

By analyzing past data, SLR can find a relationship between size and price.
This allows us to predict the price of a house given its size.
'''
# Out:
# '\nA real-world example of Simple Linear Regression (SLR) is predicting house prices based on size.\n\nX (independent variable): Size of the house (in square feet)\nY (dependent variable): Price of the house\n\nBy analyzing past data, SLR can find a relationship between size and price.\nThis allows us to predict the price of a house given its size.\n'

# %%
#5. What is the method of least squares in linear regression?

'''
The method of least squares in linear regression is a technique used to find the best-fitting line for a set of data points.
It works by minimizing the sum of the squared differences (errors) between the actual values and the predicted values:
Minimize 
Minimize ∑(Y−Y^)2
In simple terms, it chooses the line where the total prediction error is as small as possible, making the model more accurate.
'''
# Out:
# '\nThe method of least squares in linear regression is a technique used to find the best-fitting line for a set of data points.\nIt works by minimizing the sum of the squared differences (errors) between the actual values and the predicted values:\nMinimize \nMinimize ∑(Y−Y^)2\nIn simple terms, it chooses the line where the total prediction error is as small as possible, making the model more accurate.\n'

# %%
#6. What is Logistic Regression? How does it differ from Linear Regression?

'''
Logistic Regression is a statistical method used for classification problems, where the output is categorical (e.g., 0 or 1, Yes/No). It uses a sigmoid function to convert predictions into probabilities between 0 and 1.

Difference from Linear Regression:
Output:
Linear Regression → Continuous values
Logistic Regression → Categorical (probabilities/classes)
Function used:
Linear → Straight line (Y = a + bX)
Logistic → Sigmoid (S-shaped curve)
Purpose:
Linear → Prediction of numeric values
Logistic → Classification (e.g., spam detection)
In short, Linear Regression predicts quantities, while Logistic Regression predicts categories.
'''
# Out:
# '\nLogistic Regression is a statistical method used for classification problems, where the output is categorical (e.g., 0 or 1, Yes/No). It uses a sigmoid function to convert predictions into probabilities between 0 and 1.\n\nDifference from Linear Regression:\nOutput:\nLinear Regression → Continuous values\nLogistic Regression → Categorical (probabilities/classes)\nFunction used:\nLinear → Straight line (Y = a + bX)\nLogistic → Sigmoid (S-shaped curve)\nPurpose:\nLinear → Prediction of numeric values\nLogistic → Classification (e.g., spam detection)\nIn short, Linear Regression predicts quantities, while Logistic Regression predicts categories.\n'

# %%
#7. Name and briefly describe three common evaluation metrics for regression models

'''
Three common evaluation metrics for regression models are:

Mean Absolute Error (MAE)
Average of absolute differences between actual and predicted values; measures overall error.
Mean Squared Error (MSE)
Average of squared differences; penalizes larger errors more heavily.
R-squared (R²)
Indicates how well the model explains the variance in the data (ranges from 0 to 1).
'''
# Out:
# '\nThree common evaluation metrics for regression models are:\n\nMean Absolute Error (MAE)\nAverage of absolute differences between actual and predicted values; measures overall error.\nMean Squared Error (MSE)\nAverage of squared differences; penalizes larger errors more heavily.\nR-squared (R²)\nIndicates how well the model explains the variance in the data (ranges from 0 to 1).\n'

# %%
#8. What is the purpose of the R-squared metric in regression analysis?

'''
The R-squared (R²) metric measures how well a regression model explains the variability of the dependent variable.
Its purpose is to show the goodness of fit of the model.
R² = 1 → perfect fit (model explains all variation)
R² = 0 → model explains none of the variation
In short, it indicates how well the model fits the data and how much variation in Y is explained by X.
'''
# Out:
# '\nThe R-squared (R²) metric measures how well a regression model explains the variability of the dependent variable.\nIts purpose is to show the goodness of fit of the model.\nR² = 1 → perfect fit (model explains all variation)\nR² = 0 → model explains none of the variation\nIn short, it indicates how well the model fits the data and how much variation in Y is explained by X.\n'

# %%
#9. Write Python code to fit a simple linear regression model using scikit-learn and print the slope and intercept.

'''
# Import libraries
import numpy as np
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([[1], [2], [3], [4], [5]])  # Independent variable
y = np.array([2, 4, 6, 8, 10])           # Dependent variable

# Create and fit model
model = LinearRegression()
model.fit(X, y)

# Print slope and intercept
print("Slope (Coefficient):", model.coef_[0])
print("Intercept:", model.intercept_)
'''
# Out:
# '\n# Import libraries\nimport numpy as np\nfrom sklearn.linear_model import LinearRegression\n\n# Sample data\nX = np.array([[1], [2], [3], [4], [5]])  # Independent variable\ny = np.array([2, 4, 6, 8, 10])           # Dependent variable\n\n# Create and fit model\nmodel = LinearRegression()\nmodel.fit(X, y)\n\n# Print slope and intercept\nprint("Slope (Coefficient):", model.coef_[0])\nprint("Intercept:", model.intercept_)\n'

# %%
#10. How do you interpret the coefficients in a simple linear regression model?

'''
In a Simple Linear Regression model 
Y=a+bX:

Intercept (a):
It represents the value of Y when X = 0.
Slope (b):
It shows how much Y changes for a one-unit increase in X.
In simple terms, the slope indicates the strength and direction of the relationship, while the intercept gives the starting point of the line.
'''
# Out:
# '\nIn a Simple Linear Regression model \nY=a+bX:\n\nIntercept (a):\nIt represents the value of Y when X = 0.\nSlope (b):\nIt shows how much Y changes for a one-unit increase in X.\nIn simple terms, the slope indicates the strength and direction of the relationship, while the intercept gives the starting point of the line.\n'
